# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
file = "result.csv"
f = open(file, "w")
Headers = "Title,Category,Date,Summary\n"
f.write(Headers)

for page in range(1,5):
    url = "https://www.detik.com/search/searchnews?query=pemilu&sortby=time&page={}".format(page)
    html = urlopen(url)
    soup = BeautifulSoup(html,"html.parser")
    soup.prettify()
    Article = soup.find_all("article")
    #print(Article)
    for i in Article:
        try:
            #Mengambil Title
            title = i.find("h2", {"class":"title"}).get_text()
            #Mencari tanggal dan kategori
            date_and_category = i.find("span",{"class":"date"}).get_text()
            summary = i.find("p").get_text()
            #Tulis data ke dalam file
            f.write("{}".format(title).replace(",","|") + ", {}".format(date_and_category).replace("  -  ",",") + "," + ", {}".format(summary).replace(","," ") + "\n" )
        except: AttributeError
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ed38981bdf20> in <cell line: 6>()
#       6 for page in range(1,5):
#       7     url = "https://www.detik.com/search/searchnews?query=pemilu&sortby=time&page={}".format(page)
# ----> 8     html = urlopen(url)
#       9     soup = BeautifulSoup(html,"html.parser")
#      10     soup.prettify()
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     517
#     518         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519         response = self._open(req, data)
#     520
# ...
